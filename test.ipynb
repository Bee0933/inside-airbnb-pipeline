# %%
import pandas as pd
import numpy as np
import os
import ast
import glob
from typing import List
from pathlib import Path

# %%
year="2022"
# cli_fmt="2022" -- $1
avail_dates = ["12-05", "09-07", "06-05", "03-08"]
# cli_fmt="12-05 09-07 06-05 03-08" -- $2

link_listings = "http://data.insideairbnb.com/the-netherlands/north-holland/amsterdam/2022-12-05/data/listings.csv.gz"
list_calender = "http://data.insideairbnb.com/the-netherlands/north-holland/amsterdam/2022-12-05/data/calendar.csv.gz"
link_reviews = "http://data.insideairbnb.com/the-netherlands/north-holland/amsterdam/2022-12-05/data/reviews.csv.gz"


data_tables = ["listings", "calendar", "reviews"]
# cli_fmt_tables = "listings calendar reviews" -- $3



# bash run --> 
# chmod +x ./extract_data.sh
# ./extract_data.sh "2022" "12-05 09-07 06-05 03-08" "listings calendar reviews"

# %%
calender_local_path = "data/raw/2022/amsterdam/calendar/amsterdam_calendar_2022_03-08.csv.gz"
df_cal=pd.read_csv(filepath_or_buffer=calender_local_path, compression='gzip', header=0, sep=',')
display(df_cal.head())
print("row count :",df_cal.shape[0])
# Out:
#    listing_id        date available   price adjusted_price  minimum_nights  \
# 0        2818  2022-03-08         f  $49.00         $49.00             3.0
# 1        2818  2022-03-09         t  $49.00         $49.00             3.0
# 2        2818  2022-03-10         f  $50.00         $50.00             3.0
# 3        2818  2022-03-11         f  $50.00         $50.00             3.0
# 4        2818  2022-03-12         f  $50.00         $50.00             3.0
#
#    maximum_nights
# 0          1125.0
# 1          1125.0
# 2          1125.0
# 3          1125.0
# 4          1125.0
# row count : 2091085

# %% [markdown]
# ## EXTRACT

# %%
calendar_csv_dir = "data/raw/2022/amsterdam/calendar"
listings_csv_dir = "data/raw/2022/amsterdam/listings"
reviews_csv_dir = "data/raw/2022/amsterdam/reviews"


def merge_data(csv_path:Path) -> pd.DataFrame:
      csv_files = Path(csv_path).glob('*.csv.gz')
      csv_paths = list(csv_files)

      return pd.concat(
          (pd.read_csv(f, compression='gzip', header=0, sep=',')
           for f in csv_paths),
          ignore_index=True,
      )

# %%
# data = merge_data(calendar_csv_dir)
# display(data.head())
# print(data.shape[0])

# %% [markdown]
# ## TRANSFORM

# %%
# calendar
# df.date = pd.to_datetime(df.date)
# df.price = df.price.str.replace('$', '', regex=True).astype('float64')
# df.adjusted_price = df.adjusted_price.str.replace('$', '', regex=True).astype('float64')
# df


# reviews 
# df.date = pd.to_datetime(df.date)


# listings
# df.last_scraped = pd.to_datetime(df.last_scraped)
# df.description = df.description.str.replace(r'<[^<>]*>', f'{os.linesep}', regex=True)
# df.host_since = pd.to_datetime(df.host_since)
# df.host_about = df.host_about.str.replace(r'\n', f'', regex=True).replace(r'\r', f'', regex=True)
# df.host_response_rate = df.host_response_rate.str.replace('%', '', regex=True).astype('float16')
# df.host_acceptance_rate = df.host_acceptance_rate.str.replace('%', '', regex=True).astype('float16')
# df["host_verifications_phone"] = np.where("phone" in str(df.host_verifications), 't', 'f').astype('object')
# df["host_verifications_email"] = np.where("email" in str(df.host_verifications), 't', 'f').astype('object')
# df = df.drop(['host_verifications'], axis=1)
# df.price = df.price.str.replace('$', '', regex=True).astype('float64')

# # amenities
# amenit=list(df.amenities.unique())
# temp_1 = ast.literal_eval(amenit[0])
# for i in amenit[1:]:
#     temp = ast.literal_eval(i)
#     result = list(set(temp) | set(temp_1))

# col_result = [val.replace(' ', '_').replace('-', '_').replace('–','') for val in result]
# for column_head, column in zip(col_result, result):
#     df[f"{column_head}"] = np.where(column in str(df.amenities), 't', 'f').astype('object')
# df = df.drop(['amenities'], axis=1)

# df.minimum_minimum_nights = df.minimum_minimum_nights.astype('int64')
# df.maximum_minimum_nights = df.maximum_minimum_nights.astype('int64')
# df.minimum_maximum_nights = df.minimum_maximum_nights.astype('int64')
# df.maximum_maximum_nights = df.maximum_maximum_nights.astype('int64')


# df = df.drop(['calendar_last_scraped'], axis=1)
# df.first_review = pd.to_datetime(df.first_review)
# df.last_review = pd.to_datetime(df.last_review)


# df = df.rename(columns={'host_response_rate': 'host_response_rate_%', 'host_acceptance_rate': 'host_acceptance_rate_%'})

# %%
# calendar
dt = merge_data(listings_csv_dir).head()

# %%
df = dt.copy()

# %%
df.last_scraped = pd.to_datetime(df.last_scraped)
df.description = df.description.str.replace(r'<[^<>]*>', f'{os.linesep}', regex=True)
df.host_since = pd.to_datetime(df.host_since)
df.host_about = df.host_about.str.replace(r'\n', f'', regex=True).replace(r'\r', f'', regex=True)
df.host_response_rate = df.host_response_rate.str.replace('%', '', regex=True).astype('float16')
df.host_acceptance_rate = df.host_acceptance_rate.str.replace('%', '', regex=True).astype('float16')
df["host_verifications_phone"] = np.where("phone" in str(df.host_verifications), 't', 'f').astype('object')
df["host_verifications_email"] = np.where("email" in str(df.host_verifications), 't', 'f').astype('object')
df = df.drop(['host_verifications'], axis=1)
df.bedrooms = df.bedrooms.astype('int64')
df.beds = df.beds.astype('int64')
df.price = df.price.str.replace('$', '', regex=True).astype('float64')

# amenities
amenit=list(df.amenities.unique())
temp_1 = ast.literal_eval(amenit[0])
for i in amenit[1:]:
    temp = ast.literal_eval(i)
    result = list(set(temp) | set(temp_1))
    temp_1 = result

col_result = [val.replace(' ', '_').replace('-', '_').replace('–','') for val in result]
for column_head, column in zip(col_result, result):
    df[f"{column_head}"] = np.where(column in str(df.amenities), 't', 'f').astype('object')
df = df.drop(['amenities'], axis=1)

df.minimum_minimum_nights = df.minimum_minimum_nights.astype('int64')
df.maximum_minimum_nights = df.maximum_minimum_nights.astype('int64')
df.minimum_maximum_nights = df.minimum_maximum_nights.astype('int64')
df.maximum_maximum_nights = df.maximum_maximum_nights.astype('int64')


df = df.drop(['calendar_last_scraped'], axis=1)
df.first_review = pd.to_datetime(df.first_review)
df.last_review = pd.to_datetime(df.last_review)


df = df.rename(columns={'host_response_rate': 'host_response_rate_%', 'host_acceptance_rate': 'host_acceptance_rate_%'})

# %%
# amenit=list(df.amenities.unique())
# temp_1 = ast.literal_eval(amenit[0])
# for i in amenit[1:]:
#     temp = ast.literal_eval(i)
#     result = list(set(temp) | set(temp_1))

# col_result = [val.replace(' ', '_').replace('-', '_').replace('–','') for val in result]
# for column_head, column in zip(col_result, result):
#     df[f"{column_head}"] = np.where(column in str(df.amenities), 't', 'f').astype('object')
# df = df.drop(['amenities'], axis=1)

# for column_head, column in zip(col_result, result):
#     df[f"{column_head}"] = np.where(column in str(df.amenities), 't', 'f').astype('object')

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   2818   https://www.airbnb.com/rooms/2818  20220907151523   2022-09-07
# 1  20168  https://www.airbnb.com/rooms/20168  20220907151523   2022-09-07
# 2  27886  https://www.airbnb.com/rooms/27886  20220907151523   2022-09-07
# 3  28871  https://www.airbnb.com/rooms/28871  20220907151523   2022-09-07
# 4  29051  https://www.airbnb.com/rooms/29051  20220907151523   2022-09-07
#
#             source                                               name  \
# 0      city scrape           Quiet Garden View Room & Super Fast WiFi
# 1  previous scrape       Studio with private bathroom in the centre 1
# 2      city scrape  Romantic, stylish B&B houseboat in canal district
# 3      city scrape                            Comfortable double room
# 4      city scrape                            Comfortable single room
#
#                                          description  \
# 0  Quiet Garden View Room & Super Fast WiFi\n\n\n...
# 1  17th century Dutch townhouse in the heart of t...
# 2  Stylish and romantic houseboat on fantastic hi...
# 3  \nThe space\n\nIn a monumental house right in ...
# 4  This room can also accomodate 2 people.  For a...
#
#                                neighborhood_overview  \
# 0  Indische Buurt ("Indies Neighborhood") is a ne...
# 1  Located just in between famous central canals....
# 2         Central, quiet, safe, clean and beautiful.
# 3       Flower market , Leidseplein , Rembrantsplein
# 4  the street is quite lively especially on weeke...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/10272854/8dcc...     3159
# 1  https://a0.muscache.com/pictures/69979628/fd6a...    59484
# 2  https://a0.muscache.com/pictures/02c2da9d-660e...    97647
# 3  https://a0.muscache.com/pictures/160889/362340...   124245
# 4  https://a0.muscache.com/pictures/162009/bd6be2...   124245
#
#                                    host_url  host_name host_since  \
# 0    https://www.airbnb.com/users/show/3159     Daniel 2008-09-24
# 1   https://www.airbnb.com/users/show/59484  Alexander 2009-12-02
# 2   https://www.airbnb.com/users/show/97647       Flip 2010-03-23
# 3  https://www.airbnb.com/users/show/124245      Edwin 2010-05-13
# 4  https://www.airbnb.com/users/show/124245      Edwin 2010-05-13
#
#             host_location                                         host_about  \
# 0  Amsterdam, Netherlands  Upon arriving in Amsterdam, one can imagine as...
# 1  Amsterdam, Netherlands                  + (Phone number hidden by Airbnb)
# 2  Amsterdam, Netherlands  Marjan works in "eye" the dutch filmmuseum, an...
# 3  Amsterdam, Netherlands                                                 Hi
# 4  Amsterdam, Netherlands                                                 Hi
#
#   host_response_time  host_response_rate_%  host_acceptance_rate_%  \
# 0     within an hour                 100.0                   100.0
# 1     within an hour                 100.0                    98.0
# 2     within an hour                 100.0                   100.0
# 3     within an hour                 100.0                   100.0
# 4     within an hour                 100.0                   100.0
#
#   host_is_superhost                                 host_thumbnail_url  \
# 0                 t  https://a0.muscache.com/im/users/3159/profile_...
# 1                 f  https://a0.muscache.com/im/pictures/user/65092...
# 2                 f  https://a0.muscache.com/im/users/97647/profile...
# 3                 t  https://a0.muscache.com/im/pictures/user/9986b...
# 4                 t  https://a0.muscache.com/im/pictures/user/9986b...
#
#                                     host_picture_url   host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/3159/profile_...       Indische Buurt
# 1  https://a0.muscache.com/im/pictures/user/65092...       Grachtengordel
# 2  https://a0.muscache.com/im/users/97647/profile...  Westelijke Eilanden
# 3  https://a0.muscache.com/im/pictures/user/9986b...    Amsterdam Centrum
# 4  https://a0.muscache.com/im/pictures/user/9986b...    Amsterdam Centrum
#
#    host_listings_count  host_total_listings_count host_has_profile_pic  \
# 0                    1                          1                    t
# 1                    5                          5                    t
# 2                    1                          1                    t
# 3                    2                          2                    t
# 4                    2                          2                    t
#
#   host_identity_verified                          neighbourhood  \
# 0                      t  Amsterdam, North Holland, Netherlands
# 1                      t  Amsterdam, North Holland, Netherlands
# 2                      t  Amsterdam, North Holland, Netherlands
# 3                      t  Amsterdam, North Holland, Netherlands
# 4                      t  Amsterdam, North Holland, Netherlands
#
#                    neighbourhood_cleansed  neighbourhood_group_cleansed  \
# 0  Oostelijk Havengebied - Indische Buurt                           NaN
# 1                            Centrum-Oost                           NaN
# 2                            Centrum-West                           NaN
# 3                            Centrum-West                           NaN
# 4                            Centrum-Oost                           NaN
#
#    latitude  longitude                property_type     room_type  \
# 0  52.36435    4.94358  Private room in rental unit  Private room
# 1  52.36407    4.89393    Private room in townhouse  Private room
# 2  52.38761    4.89188    Private room in houseboat  Private room
# 3  52.36775    4.89092  Private room in rental unit  Private room
# 4  52.36584    4.89111  Private room in rental unit  Private room
#
#    accommodates  bathrooms    bathrooms_text  bedrooms  beds  price  \
# 0             2        NaN  1.5 shared baths         1     2   49.0
# 1             2        NaN    1 private bath         1     1  106.0
# 2             2        NaN         1.5 baths         1     1  136.0
# 3             2        NaN     1 shared bath         1     1   75.0
# 4             1        NaN     1 shared bath         1     1   55.0
#
#    minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0               3              28                       3
# 1               1             365                       1
# 2               2             356                       2
# 3               2            1825                       2
# 4               2             730                       2
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                       3                    1125                    1125
# 1                       1                    1125                    1125
# 2                       2                    1125                    1125
# 3                       2                    1825                    1825
# 4                       2                     730                     730
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 0                     3.0                  1125.0               NaN
# 1                     1.0                  1125.0               NaN
# 2                     2.0                  1125.0               NaN
# 3                     2.0                  1825.0               NaN
# 4                     2.0                   730.0               NaN
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t                1                9               14
# 1                t                0                0                0
# 2                t                0                0               14
# 3                t                4                6                8
# 4                t                0                4                5
#
#    availability_365  number_of_reviews  number_of_reviews_ltm  \
# 0                14                305                     25
# 1                 0                339                      0
# 2               121                231                      8
# 3               117                428                     75
# 4               160                582                     86
#
#    number_of_reviews_l30d first_review last_review  review_scores_rating  \
# 0                       1   2009-03-30  2022-08-30                  4.89
# 1                       0   2010-03-02  2020-04-09                  4.44
# 2                       0   2012-01-09  2022-04-24                  4.94
# 3                       5   2010-08-22  2022-08-24                  4.88
# 4                       7   2011-03-16  2022-08-29                  4.79
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    4.94                       5.00                   4.97
# 1                    4.69                       4.79                   4.63
# 2                    4.92                       4.95                   4.95
# 3                    4.94                       4.89                   4.96
# 4                    4.88                       4.84                   4.92
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.98                    4.69                 4.82
# 1                         4.62                    4.87                 4.49
# 2                         4.92                    4.89                 4.79
# 3                         4.94                    4.96                 4.83
# 4                         4.92                    4.87                 4.77
#
#                     license instant_bookable  calculated_host_listings_count  \
# 0  0363 5F3A 5684 6750 D14D                t                               1
# 1  0363 CBB3 2C10 0C2A 1E29                t                               2
# 2  0363 974D 4986 7411 88D8                t                               1
# 3  0363 607B EA74 0BD8 2F6F                f                               2
# 4  0363 607B EA74 0BD8 2F6F                f                               2
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             1
# 1                                             2
# 2                                             1
# 3                                             2
# 4                                             2
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month  \
# 0                                            0               1.86
# 1                                            0               2.22
# 2                                            0               1.78
# 3                                            0               2.92
# 4                                            0               4.16
#
#   host_verifications_phone host_verifications_email Single_level_home  \
# 0                        t                        t                 f
# 1                        t                        t                 f
# 2                        t                        t                 f
# 3                        t                        t                 f
# 4                        t                        t                 f
#
#   Paid_parking_off_premises Hair_dryer Hp_neutral,_eco_friendly_body_soap  \
# 0                         f          f                                  f
# 1                         f          f                                  f
# 2                         f          f                                  f
# 3                         f          f                                  f
# 4                         f          f                                  f
#
#   Lake_access Portable_fans First_aid_kit Fast_wifi__52_Mbps Heating  \
# 0           f             f             f                  f       f
# 1           f             f             f                  f       f
# 2           f             f             f                  f       f
# 3           f             f             f                  f       f
# 4           f             f             f                  f       f
#
#   Carbon_monoxide_alarm Smart_lock Smoke_alarm Mini_fridge  \
# 0                     f          f           f           f
# 1                     f          f           f           f
# 2                     f          f           f           f
# 3                     f          f           f           f
# 4                     f          f           f           f
#
#   Shared_fenced_garden_or_backyard Wifi Dining_table Essentials  \
# 0                                f    t            f          f
# 1                                f    t            f          f
# 2                                f    t            f          f
# 3                                f    t            f          f
# 4                                f    t            f          f
#
#   Host_greets_you Bed_linens Safe Dryer Shower_gel Cleaning_products  \
# 0               f          f    t     f          f                 f
# 1               f          f    t     f          f                 f
# 2               f          f    t     f          f                 f
# 3               f          f    t     f          f                 f
# 4               f          f    t     f          f                 f
#
#   Paid_street_parking_off_premises Free_street_parking Refrigerator Boat_slip  \
# 0                                f                   f            t         f
# 1                                f                   f            t         f
# 2                                f                   f            t         f
# 3                                f                   f            t         f
# 4                                f                   f            t         f
#
#   Outdoor_furniture Security_cameras_on_property TV Mosquito_net  \
# 0                 f                            f  t            f
# 1                 f                            f  t            f
# 2                 f                            f  t            f
# 3                 f                            f  t            f
# 4                 f                            f  t            f
#
#   Central_heating Drying_rack_for_clothing TV_with_standard_cable  \
# 0               f                        f                      f
# 1               f                        f                      f
# 2               f                        f                      f
# 3               f                        f                      f
# 4               f                        f                      f
#
#   Nespresso_machine Private_patio_or_balcony Room_darkening_shades  \
# 0                 f                        f                     f
# 1                 f                        f                     f
# 2                 f                        f                     f
# 3                 f                        f                     f
# 4                 f                        f                     f
#
#   Paid_parking_on_premises Lock_on_bedroom_door Clothing_storage:_wardrobe  \
# 0                        f                    f                          f
# 1                        f                    f                          f
# 2                        f                    f                          f
# 3                        f                    f                          f
# 4                        f                    f                          f
#
#   Dishes_and_silverware Private_garden_or_backyard Private_entrance Kayak  \
# 0                     f                          f                t     f
# 1                     f                          f                t     f
# 2                     f                          f                t     f
# 3                     f                          f                t     f
# 4                     f                          f                t     f
#
#   Hot_water_kettle  \
# 0                f
# 1                f
# 2                f
# 3                f
# 4                f
#
#   Sony_+_Wireless_Bluetooth_Speaker(phone)_Bluetooth_sound_system  \
# 0                                                  f
# 1                                                  f
# 2                                                  f
# 3                                                  f
# 4                                                  f
#
#   Paid_washer__In_unit Cable_TV Outdoor_dining_area Long_term_stays_allowed  \
# 0                    f        f                   f                       f
# 1                    f        f                   f                       f
# 2                    f        f                   f                       f
# 3                    f        f                   f                       f
# 4                    f        f                   f                       f
#
#   Dedicated_workspace Ethernet_connection Hangers  \
# 0                   f                   f       f
# 1                   f                   f       f
# 2                   f                   f       f
# 3                   f                   f       f
# 4                   f                   f       f
#
#   PH_neutral_and_dermatologically_tested_shampoo Fire_extinguisher  \
# 0                                              f                 t
# 1                                              f                 t
# 2                                              f                 t
# 3                                              f                 t
# 4                                              f                 t
#
#   Wine_glasses Shampoo PH_neutral_and_dermatologically_tested_body_soap  \
# 0            f       t                                                f
# 1            f       t                                                f
# 2            f       t                                                f
# 3            f       t                                                f
# 4            f       t                                                f
#
#   Luggage_dropoff_allowed Clothing_storage:_closet Hot_water Breakfast  \
# 0                       f                        f         f         f
# 1                       f                        f         f         f
# 2                       f                        f         f         f
# 3                       f                        f         f         f
# 4                       f                        f         f         f
#
#   Waterfront Laundromat_nearby Extra_pillows_and_blankets Bikes Coffee_maker  \
# 0          f                 f                          f     f            f
# 1          f                 f                          f     f            f
# 2          f                 f                          f     f            f
# 3          f                 f                          f     f            f
# 4          f                 f                          f     f            f
#
#   Iron
# 0    t
# 1    t
# 2    t
# 3    t
# 4    t

# %% [markdown]
# ## LOAD Local

# %%
processed_dir = "./data/processed/listings/"
os.makedirs(processed_dir, exist_ok=True)
df.to_parquet(f'{processed_dir}listings.parquet', engine='fastparquet', compression='snappy')

# %% [markdown]
# ## remove old data

# %%
rm_path = "data/processed/listings"
ext = "parquet"

def delete_files_and_dir(dir:Path, file_extension:str)->List[Path]:
    files_in_dir = []
    for f in glob.glob(f"{rm_path}/*.{file_extension}"):
        os.remove(f)
        files_in_dir.append(f)
    os.removedirs(rm_path)
    return f" deleted files : {files_in_dir}"

# %%
delete_files_and_dir(rm_path,ext)
# Out:
# " deleted files : ['data/processed/listings/listings.parquet', 'data/processed/listings/listings0.parquet', 'data/processed/listings/listings00.parquet']"
